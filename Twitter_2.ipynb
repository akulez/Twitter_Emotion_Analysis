# %%
# %run "C:\Users\AM3855\Desktop\Twitter_1.ipynb"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10314 entries, 0 to 10313
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Text      10314 non-null  object
#  1   Category  10314 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 161.3+ KB
# Requirement already satisfied: wordcloud in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# INSTALLING PACKAGES FOR PREPROCESSING

# %pip install textacy
# %pip install nltk
# Out:
# Collecting textacy
#   Downloading textacy-0.13.0-py3-none-any.whl (210 kB)
#      -------------------------------------- 210.7/210.7 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from textacy) (1.23.5)
# Requirement already satisfied: tqdm>=4.19.6 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from textacy) (4.64.1)
# Requirement already satisfied: jellyfish>=0.8.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from textacy) (0.9.0)
# Requirement already satisfied: cytoolz>=0.10.1 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from textacy) (0.12.0)
# Collecting floret~=0.10.0
#   Downloading floret-0.10.3-cp310-cp310-win_amd64.whl (239 kB)
#      -------------------------------------- 239.6/239.6 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.7 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from textacy) (2.8.4)
# Requirement already satisfied: requests>=2.10.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from textacy) (2.28.1)
# Requirement already satisfied: joblib>=0.13.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from textacy) (1.1.1)
# Collecting catalogue~=2.0
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from textacy) (1.10.0)
# Collecting pyphen>=0.10.0
#   Downloading pyphen-0.14.0-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from textacy) (1.2.1)
# Collecting cachetools>=4.0.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting spacy~=3.0
#   Downloading spacy-3.5.3-cp310-cp310-win_amd64.whl (12.2 MB)
#      ---------------------------------------- 12.2/12.2 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: toolz>=0.8.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from cytoolz>=0.10.1->textacy) (0.12.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from requests>=2.10.0->textacy) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from requests>=2.10.0->textacy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from requests>=2.10.0->textacy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from requests>=2.10.0->textacy) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=1.0->textacy) (2.2.0)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.1-py3-none-any.whl (27 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      -------------------------------------- 181.6/181.6 kB 2.2 MB/s eta 0:00:00
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp310-cp310-win_amd64.whl (29 kB)
# Collecting typer<0.8.0,>=0.3.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from spacy~=3.0->textacy) (22.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.8-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 2.2 MB/s eta 0:00:00
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp310-cp310-win_amd64.whl (94 kB)
#      ---------------------------------------- 94.7/94.7 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from spacy~=3.0->textacy) (3.1.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from spacy~=3.0->textacy) (5.2.1)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.6-cp310-cp310-win_amd64.whl (480 kB)
#      -------------------------------------- 480.9/480.9 kB 2.3 MB/s eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp310-cp310-win_amd64.whl (18 kB)
# Requirement already satisfied: setuptools in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from spacy~=3.0->textacy) (65.6.3)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.10-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 2.0 MB/s eta 0:00:00
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.1-py3-none-any.whl (48 kB)
#      ---------------------------------------- 48.9/48.9 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.19.6->textacy) (0.4.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy~=3.0->textacy) (4.4.0)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp310-cp310-win_amd64.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 2.2 MB/s eta 0:00:00
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.4-py3-none-any.whl (32 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy~=3.0->textacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from jinja2->spacy~=3.0->textacy) (2.1.1)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, pyphen, pydantic, murmurhash, langcodes, floret, catalogue, cachetools, blis, typer, srsly, preshed, pathy, confection, thinc, spacy, textacy
# Successfully installed blis-0.7.9 cachetools-5.3.1 catalogue-2.0.8 confection-0.0.4 cymem-2.0.7 floret-0.10.3 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.8 pyphen-0.14.0 spacy-3.5.3 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.6 textacy-0.13.0 thinc-8.1.10 typer-0.7.0 wasabi-1.1.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nltk in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from nltk) (1.1.1)
# Requirement already satisfied: click in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: colorama in c:\users\am3855\appdata\local\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# IMPORT OTHER TEXT PREPROCESSING LIBRARIES

import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
from textacy import preprocessing
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\AM3855\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AM3855\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AM3855\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\AM3855\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# SHUFFLING OUR DATASET SINCE IT IS IS UNSHUFFLED AND FIRST 8000 ROWS BELONGED TO A CERTAIN CATEGORY

data = data.sample(frac=1)

# %%
# CONVERTING TEXT TO LOWER CASE

data["Text"] = data["Text"].str.lower()

# %%
# REMOVING THE STOPWORDS

stop = stopwords.words('english')

data["Text"] = data['Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
# REMOVING PUNCTUATION, EXTRA WHITESPACES AND HASHTAGS

preprocess = preprocessing.make_pipeline(
    preprocessing.remove.punctuation,
    preprocessing.normalize.whitespace,
    preprocessing.replace.hashtags,
)

data["Text"] = data["Text"].apply(preprocess)

# %%
# STEMMING THE WORDS

from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
data['Text'] = data['Text'].apply(lambda x: stemmer.stem(x))

# %%
# REVIEW THE DATA AFTER TEXT PREPROCESSING

data.head()
# Out:
#                                                     Text  Category
# 5558   so take next msg personal ur name mention caus...         0
# 894              enrique iglesias denmark woooaw coool b         0
# 10071  anxiety keeps awake antsy depression makes unm...         1
# 1847                 mommyto6kids omg that s crazy weath         0
# 6539                             cynthiaburoughs hugs bk         0

# %%
# CREATING WORDCLOUD TO SEE MOST OCCURING WORDS AFTER PREPROCESSING

TEXT_AFTER_PREPROCESS = data['Text'].values 

wordcloud = WordCloud().generate(str(TEXT_AFTER_PREPROCESS))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()
plt.figure(figsize = (40,40), facecolor = None)

# %%
# IMPORTING LIBRARY TO IMPLEMENT TF-IDF ALGORITHM

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#CREATING CORPUS OF OUR WORDS

corpus = data['Text'].tolist()

# %%
# PRINTING NO. OF WORDS OF OUR CORPUS

print("Total no. of words in our corpus are:", len(corpus),'\n')
# Out:
# Total no. of words in our corpus are: 10283

# %%
# FITTING VECTORIZER TO OUR DATA

vectorizer = TfidfVectorizer()
vectorizer.fit(corpus)
# Out:
# TfidfVectorizer()

# %%
# TRANSFORMING OUR DATA

Text_tf = vectorizer.transform(data['Text']).toarray()

# %%
# GETTING TOP 5 WORDS WITH HIGHEST TF-IDF SCORES

feature_array = np.array(vectorizer.get_feature_names_out())
tfidf_sorting = np.argsort(Text_tf).flatten()[::-1]

n = 5
top_n = feature_array[tfidf_sorting][:n]
print("The 5 most important words are", top_n, '\n')
# Out:
# The 5 most important words are ['pasta' 'oops' 'fell' 'asleep' 'hours']

# %%
# GETTING WORDS WITH THE LEAST TF-IDF SCORES

bottom_n = feature_array[tfidf_sorting][-n:]
print(" The 5 least important words having lowest tf-idf scores are", bottom_n)
print('\n')
# Out:
#  The 5 least important words having lowest tf-idf scores are ['part' 'partayyyi' 'parti' 'participants' '00']

# %%
# REVIEW ONE OF THE VECTORIZED SENTENCE

Text_tf[1]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# RECHEKING LENGTH OF OUR VECTORIZED ARRAY

print("Length of our vectorized array is:",len(Text_tf), "\n")
# Out:
# Length of our vectorized array is: 10283

# %%
# VISUALIZING OUR TF-IDF VECTOR IN 2-D USING PCA

from sklearn.decomposition import PCA
# %matplotlib inline

pca = PCA(n_components=2)

df2d = pd.DataFrame(pca.fit_transform(Text_tf), columns=list('xy'))

print('\n', "Our TF-IDF Vector in 2-D Looks like:",'\n')
df2d.plot(kind='scatter', x='x', y='y')
plt.show()
# Out:
#  Our TF-IDF Vector in 2-D Looks like:

# %%
# SPLITTING OUR VECTORIZED ARRAY TO TRAINING AND TESTING USING THE 80-20 RULE

x_train = Text_tf[:8000]
x_test = Text_tf[8000:]

# %%
# SPLITTING OUR DEPENDENT VARIABLE INTO TRAINING AND TESTING

y_train = data["Category"].iloc[:8000]
y_test = data["Category"].iloc[8000:]
